# %% [markdown]
# <a href="https://colab.research.google.com/github/biswalsaroj/Data_Science/blob/main/Assignment_session_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
CUSTOMER_MASTER=pd.read_excel(r'https://raw.githubusercontent.com/biswalsaroj/Data_Science/refs/heads/main/CUSTOMER_MASTER.xlsx')
CUSTOMER_MASTER
# Out:
#     CUSTOMER_ID     CUSTOMER NAME CUSTOMER_SSN           CITY  MARKET  \
# 0    1000032547       Rick Hansen     RH-19495  New York City      US
# 1    1000032548     Justin Ritter     JR-16210     Wollongong    APAC
# 2    1000032549      Craig Reiter     CR-12730       Brisbane    APAC
# 3    1000032550  Katherine Murray     KM-16375         Berlin      EU
# 4    1000032551       Rick Hansen      RH-9495          Dakar  Africa
# 5    1000032552       Jim Mitchum          NaN         Sydney    APAC
# 6    1000032553     Toby Swindell     TS-21340        Porirua    APAC
# 7    1000032554        Mick Brown     MB-18085       Hamilton    APAC
# 8    1000032555         Jane Waco     JW-15220     Sacramento      US
# 9    1000032556       Joseph Holt     JH-15985        Concord      US
# 10   1000032557      Greg Maxwell     GM-14695     Alexandria      US
# 11   1000032558    Anthony Jacobs     AJ-10780            NaN    APAC
# ...

# %%
#GET NUMBER OF COLUMNS AND RECORDS IN THE DATASET

# %%
CUSTOMER_MASTER.shape
# Out:
# (21, 7)

# %%
#GET THE LIST OF COLUMNS HEADERS NAME

# %%
CUSTOMER_MASTER.columns
# Out:
# Index(['CUSTOMER_ID', 'CUSTOMER NAME', 'CUSTOMER_SSN', 'CITY', 'MARKET', 'DOB',
#        'TOWN'],
#       dtype='object')

# %%
#GET FIRST 3 RECORDS FROM THE DATASET

# %%
CUSTOMER_MASTER.head(3)
# Out:
#    CUSTOMER_ID  CUSTOMER NAME CUSTOMER_SSN           CITY MARKET        DOB  \
# 0   1000032547    Rick Hansen     RH-19495  New York City     US 1984-09-15
# 1   1000032548  Justin Ritter     JR-16210     Wollongong   APAC 1974-07-15
# 2   1000032549   Craig Reiter     CR-12730       Brisbane   APAC 1959-04-01
#
#             TOWN
# 0        Kyabram
# 1  Hawthorn East
# 2        Revesby

# %%
#GET LAST 3 RECORDS FROM THE DATASET

# %%
CUSTOMER_MASTER.tail(3)
# Out:
#     CUSTOMER_ID    CUSTOMER NAME CUSTOMER_SSN        CITY  MARKET        DOB  \
# 18   1000032565         Jim Sink          NaN  Townsville    APAC 1949-09-30
# 19   1000032566  Ritsa Hightower      RH-9555      Uvinza  Africa 1948-10-21
# 20   1000032567        Ann Blume       AB-600       Bytom    EMEA 1972-05-31
#
#                TOWN
# 18            Menai
# 19              NaN
# 20  BARRACK HEIGHTS

# %%
#GET VARIABLES DATA TYPES

# %%
CUSTOMER_MASTER.dtypes
# Out:
# CUSTOMER_ID               int64
# CUSTOMER NAME            object
# CUSTOMER_SSN             object
# CITY                     object
# MARKET                   object
# DOB              datetime64[ns]
# TOWN                     object
# dtype: object

# %%
#GET THE TOTAL MISSING RECORDS IN THE DATASET

# %%
CUSTOMER_MASTER.isnull().sum().sum()
# Out:
# np.int64(6)

# %%
#GET THE TOTAL MISSING RECORDS IN THE VARIABLE CUSTOMER_SSN

# %%
CUSTOMER_MASTER['CUSTOMER_SSN'].isnull().sum().sum()
# Out:
# np.int64(2)

# %% [markdown]
# # **Task-3**

# %%
ACCOUNT_PERF_CSV=pd.read_csv(r'https://raw.githubusercontent.com/biswalsaroj/Data_Science/refs/heads/main/ACCOUNT_PERF_DATA.csv')
ACCOUNT_PERF_CSV
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %%
ACCOUNT_PERF_EXCEL=pd.read_excel(r'https://raw.githubusercontent.com/biswalsaroj/Data_Science/refs/heads/main/ACCOUNT_PERF_DATA.xlsx')
ACCOUNT_PERF_EXCEL
# Out:
#        Account_number      PORTFOLIO          SSN    Phone No.   \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %%
ACCOUNT_PERF_EXCEL.columns
# Out:
# Index(['Account_number', 'PORTFOLIO', 'SSN', 'Phone No. ', 'Place Name',
#        'County', 'City', 'State', 'Zip', 'Region', 'Account Open Date',
#        'Loan_amount', 'Loan_status', 'Last_payment_date',
#        'Origination_fico_score', 'Current_fico_score', 'Current_outstanding'],
#       dtype='object')

# %%
ACCOUNT_PERF_EXCEL.rename(columns={'Phone No. ':'Phone_No','Account Open Date':'Account_Open_Date'}, inplace=True)
ACCOUNT_PERF_EXCEL
# Out:
#        Account_number      PORTFOLIO          SSN      Phone_No  \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#            Place Name      County            City State    Zip     Region  \
# 0             Bromide    Johnston         Bromide    OK  74530      South
# ...

# %%
# WRITE PROGRAM TO CREATE A NEW DATASET AS ACCOUNT_PERF_V1 FROM ACCOUNT_PERF_EXCEL
#keep varibales Account_number
#PORTFOLIO

#SSN

#Phone No.

#City

#State

#Account Open Date

#Loan_amount

#Origination_fico_score

#Current_fico_score

#Current_outstanding '''

# %%
 ACCOUNT_PERF_V1=ACCOUNT_PERF_EXCEL[['Account_number','PORTFOLIO','SSN','Phone_No','City','State','Account_Open_Date','Loan_amount','Origination_fico_score','Current_fico_score','Current_outstanding']]
 ACCOUNT_PERF_V1
# Out:
#        Account_number      PORTFOLIO          SSN      Phone_No  \
# 0            38673575    CREDIT CARD  640-29-9264  405-775-9884
# 1            38673576  PERSONAL LOAN  375-37-8517  212-786-7533
# 2            38673577  PERSONAL LOAN  073-02-5563  385-775-0225
# 3            38673578       MORTGAGE  106-98-7919  216-984-8974
# 4            38673579    CREDIT CARD  753-07-4655  217-307-8597
# ...               ...            ...          ...           ...
# 24999        38698574    CREDIT CARD  112-98-5765  201-857-6904
# 25000        38698575  PERSONAL LOAN  507-57-2035  209-410-5762
# 25001        38698576       MORTGAGE  094-02-7375  212-698-6318
# 25002        38698577  PERSONAL LOAN  467-99-0614  212-525-5734
# 25003        38698578       MORTGAGE  191-86-1363  229-974-6770
#
#                  City State Account_Open_Date  Loan_amount  \
# 0             Bromide    OK        2018-03-13        40169
# 1      Reading Center    NY        2019-06-23       187055
# ...
